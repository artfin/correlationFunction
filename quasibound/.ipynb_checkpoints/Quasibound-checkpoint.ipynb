# %%
# %matplotlib notebook

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# matplotlib plotting parameters
mpl.rcParams['text.usetex'] = True
mpl.rcParams['text.latex.unicode'] = True

mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['font.serif'] = 'Times'
mpl.rcParams['figure.titlesize'] = 'xx-large'
mpl.rcParams['axes.labelsize'] = 'x-large'
mpl.rcParams['axes.titlesize'] = 'large'
mpl.rcParams['xtick.labelsize'] = 'large'
mpl.rcParams['ytick.labelsize'] = 'large'

# подключаем пакеты для рендеринга русского текста в LaTeX
mpl.rc('text.latex', preamble=r'\usepackage{amsmath}')
mpl.rc('text.latex', preamble=r"\usepackage[utf8]{inputenc}")
mpl.rc('text.latex', preamble=r"\usepackage[russian]{babel}")

# %%
effpot_1_50 = np.loadtxt('./pot/effpot_j=1.500000.txt')
effpot_2_50 = np.loadtxt('./pot/effpot_j=2.500000.txt')
effpot_3_50 = np.loadtxt('./pot/effpot_j=3.500000.txt')
effpot_4_50 = np.loadtxt('./pot/effpot_j=4.500000.txt')
effpot_5_50 = np.loadtxt('./pot/effpot_j=5.500000.txt')
effpot_6_50 = np.loadtxt('./pot/effpot_j=6.500000.txt')
effpot_7_50 = np.loadtxt('./pot/effpot_j=7.500000.txt')
effpot_8_50 = np.loadtxt('./pot/effpot_j=8.500000.txt')
effpot_9_50 = np.loadtxt('./pot/effpot_j=9.500000.txt')
effpot_10_50 = np.loadtxt('./pot/effpot_j=10.500000.txt')
effpot_11_00 = np.loadtxt('./pot/effpot_j=11.000000.txt')

fig = plt.figure()
plt.plot( effpot_1_50[:,0], effpot_1_50[:,1], color = 'k', lw = 1.0)
plt.plot( effpot_2_50[:,0], effpot_2_50[:,1], color = 'k', lw = 1.0)
plt.plot( effpot_3_50[:,0], effpot_3_50[:,1], color = 'k', lw = 1.0)
plt.plot( effpot_4_50[:,0], effpot_4_50[:,1], color = 'k', lw = 1.0)
plt.plot( effpot_5_50[:,0], effpot_5_50[:,1], color = 'k', lw = 1.0)
plt.plot( effpot_6_50[:,0], effpot_6_50[:,1], color = 'k', lw = 1.0)
plt.plot( effpot_7_50[:,0], effpot_7_50[:,1], color = 'k', lw = 1.0)
plt.plot( effpot_8_50[:,0], effpot_8_50[:,1], color = 'k', lw = 1.0)
plt.plot( effpot_9_50[:,0], effpot_9_50[:,1], color = 'k', lw = 1.0)
plt.plot( effpot_10_50[:,0], effpot_10_50[:,1], color = 'k', lw = 1.0)
plt.plot( effpot_11_00[:,0], effpot_11_00[:,1], color = 'k', lw = 1.0)

plt.xlim((0.0, 20.0))
plt.ylim((-1e-4, 1.2e-4))
plt.grid(linestyle = ':', alpha = 0.7)
# ////////////////////////////////////////////////////////////////////////////
maxima = np.loadtxt('./result.txt')
spline_maxima = np.loadtxt('./spline.txt')

fig = plt.figure()
plt.xlabel('J')
plt.ylabel('xmax')
plt.plot( maxima[:,0], maxima[:,1], 'o', color = 'r', markersize = 3)
plt.plot( spline_maxima[:,0], spline_maxima[:,1], color = 'k', lw = 1.0)

plt.grid(linestyle = ':', alpha = 0.7)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
